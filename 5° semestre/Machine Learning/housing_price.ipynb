# %%
# importar acesso ao Gooogle Drive
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
base = pd.read_csv('/content/drive/MyDrive/dados/Housing_Price_Data.csv')

# %%
base
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
base.tail() # tail mostras as 5 ultimas linhas, o parametro permite escolher mais linhas
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
base1 = base.drop_duplicates(subset=["price"]) # remove linhas duplicadas

# %%
base1[0:20]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420         4          2        3      yes        no       no
# 1   12250000  8960         4          4        4      yes        no       no
# 3   12215000  7500         4          2        2      yes        no      yes
# 4   11410000  7420         4          1        2      yes       yes      yes
# 5   10850000  7500         3          3        1      yes        no      yes
# 6   10150000  8580         4          3        4      yes        no       no
# 8    9870000  8100         4          1        2      yes       yes      yes
# 9    9800000  5750         3          2        4      yes       yes       no
# 11   9681000  6000         4          3        2      yes       yes      yes
# 12   9310000  6550         4          2        2      yes        no       no
# 13   9240000  3500         4          2        2      yes        no       no
# ...

# %%
import seaborn as sns
sns.histplot(base["price"], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
base.describe() # identifica outliers (pontos isolados)
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
from matplotlib import pyplot as plt
#Desenhar um boxplot para a coluna expectativa de vida
dados = base["price"]
# Definindo as dimensões e plotando o boxplot
plt.figure(figsize=(8, 6))
# cria dicionário de dados
boxplot_dict = sns.boxplot(dados)
plt.title('Boxplot da análise de Preços')
plt.xlabel('Conjunto de dados')
plt.ylabel('Valores')
plt.grid(True)
# Obtem eixos do gráfico ANTES DE MOSTRAR O GRÁFICO
ax = plt.gca()
# Acessa as linhas que representam whiskers (limites) and quartis
lines = ax.get_lines()
# As linhas são:
# 0: limite inferior, 1: limite superior, 2: mediana

# %%
from matplotlib import pyplot as plt
#Desenhar um boxplot para a coluna expectativa de vida
dados = base["area"]
# Definindo as dimensões e plotando o boxplot
plt.figure(figsize=(8, 6))
# cria dicionário de dados
boxplot_dict = sns.boxplot(dados)
plt.title('Boxplot da análise de preços')
plt.xlabel('Conjunto de dados')
plt.ylabel('Valores')
plt.grid(True)
# Obtem eixos do gráfico ANTES DE MOSTRAR O GRÁFICO
ax = plt.gca()
# Acessa as linhas que representam whiskers (limites) and quartis
lines = ax.get_lines()
# As linhas são:
# 0: limite inferior, 1: limite superior, 2: mediana

# %%
prim_quartil = lines[0].get_ydata()[0] # descreve os valores pedidos
terc_quartil = lines[1].get_ydata()[0]
lim_inf_premio = lines[0].get_ydata()[1]
lim_sup_premio = lines[1].get_ydata()[1]
# obter mediana
mediana_premio = lines[4].get_ydata()[1]
print("Limite superior do boxplot:", lim_sup_premio)
print("3o quartil do boxplot:", terc_quartil)
print("Mediana do primeiro conjunto de dados:",
mediana_premio)
print("1o quartil do boxplot:", prim_quartil)
print("Limite inferior do boxplot:", lim_inf_premio)
# Out:
# Limite superior do boxplot: 10500.0
# 3o quartil do boxplot: 6360.0
# Mediana do primeiro conjunto de dados: 4600.0
# 1o quartil do boxplot: 3600.0
# Limite inferior do boxplot: 1650.0

# %%
#necessário para o gráfico
import plotly.express as px
#gráfico
grafico = px.scatter_matrix(base, dimensions=['price','area'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#separar apenas atributos numéricos
base_separada = base.loc[:, ['area', 'price']]
# Matriz de correlação
sns.heatmap(base_separada.corr(), annot=True, cmap="Oranges")
plt.show() # exibe o grafico (ultimamente n tá mais sendo necessário, pois já exibe sozinho)

# %%
base2 = base[(base["price"]<10000)|(base["area"]<1740)] # compara e mostra so dados especificos
base2
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 449  3150000  1650         3          1        2       no        no      yes
# 537  1890000  1700         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 449              no              no        0       no      unfurnished
# 537              no              no        0       no      unfurnished
