# %% [markdown]
# # Monta o acesso ao Drive

# %%
# importar acesso ao Gooogle Drive
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # importar a biblioteca Pandas para a manipulação dos dados e abrir o arquivo excel

# %%
import pandas as pd

base = pd.read_excel('/content/drive/MyDrive/dados/felicidade.xlsx')

# %%
base.head() #colocar head mostra as 5 primeiras linhas, o parametro permite mostrar mais
# Out:
#    Id  Grau de Felicidade (0-10)  Idade Tipo de Alimentação  \
# 0   1                        8.5   35.0         Vegetariana
# 1   2                        6.2   45.0             Onívora
# 2   3                        9.0   28.0              Vegana
# 3   4                        5.5   60.0             Onívora
# 4   5                        7.8   42.0        Pescetariana
#
#    Expectativa de Vida
# 0                 78.0
# 1                 72.0
# 2                 82.0
# 3                 68.0
# 4                 75.0

# %%
base.tail() # tail mostras as 5 ultimas linhas, o parametro permite escolher mais linhas
# Out:
#       Id  Grau de Felicidade (0-10)  Idade Tipo de Alimentação  \
# 96    97                        5.6   58.0                 NaN
# 97    98                        7.7   25.0        Pescetariana
# 98    99                        8.2   48.0         Vegetariana
# 99   100                        6.9   37.0             Onívora
# 100  101                        4.8   55.0              Vegana
#
#      Expectativa de Vida
# 96                  75.0
# 97                  82.0
# 98                  90.0
# 99                  75.0
# 100                 68.0

# %%
base[10:20] # range q mostra as linhas do 10 ao 20
# Out:
#     Id  Grau de Felicidade (0-10)  Idade Tipo de Alimentação  \
# 10  11                        8.3   38.0              Vegana
# 11  12                        6.9   50.0        Pescetariana
# 12  13                        5.7   63.0         Vegetariana
# 13  14                        7.2   48.0             Onívora
# 14  15                        8.9   30.0                 NaN
# 15  16                        4.6   70.0        Pescetariana
# 16  17                        7.1   45.0                 NaN
# 17  18                        6.3    NaN              Vegana
# 18  19                        5.9    NaN             Onívora
# 19  20                        9.2   32.0        Pescetariana
#
#     Expectativa de Vida
# 10                 92.0
# 11                 90.0
# 12                 65.0
# 13                 70.0
# 14                 50.0
# 15                100.0
# 16                 55.0
# 17                145.0
# 18                138.0
# 19                 80.0

# %%
base1 = base.drop_duplicates(subset=["Idade", "Expectativa de Vida"]) # remove linhas duplicadas

# %%
base1[0:20]
# Out:
#     Id  Grau de Felicidade (0-10)  Idade Tipo de Alimentação  \
# 0    1                        8.5   35.0         Vegetariana
# 1    2                        6.2   45.0             Onívora
# 2    3                        9.0   28.0              Vegana
# 3    4                        5.5   60.0             Onívora
# 4    5                        7.8   42.0        Pescetariana
# 5    6                        6.0   50.0             Onívora
# 6    7                        8.7   32.0         Vegetariana
# 7    8                        5.2   55.0              Vegana
# 8    9                        7.0   38.0             Onívora
# 9   10                        9.5   25.0        Pescetariana
# 10  11                        8.3   38.0              Vegana
# 11  12                        6.9   50.0        Pescetariana
# 12  13                        5.7   63.0         Vegetariana
# 13  14                        7.2   48.0             Onívora
# 14  15                        8.9   30.0                 NaN
# 15  16                        4.6   70.0        Pescetariana
# 16  17                        7.1   45.0                 NaN
# 17  18                        6.3    NaN              Vegana
# 18  19                        5.9    NaN             Onívora
# 20  21                        3.8  160.0         Vegetariana
#
#     Expectativa de Vida
# 0                  78.0
# 1                  72.0
# 2                  82.0
# 3                  68.0
# 4                  75.0
# 5                  70.0
# 6                  80.0
# 7                  65.0
# 8                  74.0
# 9                  85.0
# 10                 92.0
# 11                 90.0
# 12                 65.0
# 13                 70.0
# 14                 50.0
# 15                100.0
# 16                 55.0
# 17                145.0
# 18                138.0
# 20                 -5.0

# %%
import seaborn as sns
sns.histplot(base["Idade"], kde=True)
# Out:
# <Axes: xlabel='Idade', ylabel='Count'>

# %%
base.describe() # identifica outliers (pontos isolados)
# Out:
#                Id  Grau de Felicidade (0-10)       Idade  Expectativa de Vida
# count  101.000000                 100.000000   94.000000           100.000000
# mean    51.000000                   6.906000   54.021277            77.890000
# std     29.300171                   1.524137   36.514242            27.984085
# min      1.000000                   3.800000   20.000000           -10.000000
# 25%     26.000000                   5.700000   35.000000            68.000000
# 50%     51.000000                   6.900000   45.000000            75.000000
# 75%     76.000000                   8.200000   55.000000            85.000000
# max    101.000000                   9.500000  180.000000           180.000000

# %% [markdown]
# # Fazendo Bloxpot

# %%
from matplotlib import pyplot as plt
#Desenhar um boxplot para a coluna expectativa de vida
dados = base["Expectativa de Vida"]
# Definindo as dimensões e plotando o boxplot
plt.figure(figsize=(8, 6))
# cria dicionário de dados
boxplot_dict = sns.boxplot(dados)
plt.title('Boxplot da análise de Felicidade')
plt.xlabel('Conjunto de dados')
plt.ylabel('Valores')
plt.grid(True)
# Obtem eixos do gráfico ANTES DE MOSTRAR O GRÁFICO
ax = plt.gca()
# Acessa as linhas que representam whiskers (limites) and quartis
lines = ax.get_lines()
# As linhas são:
# 0: limite inferior, 1: limite superior, 2: mediana

# %%
from matplotlib import pyplot as plt
#Desenhar um boxplot para a coluna expectativa de vida
dados = base["Grau de Felicidade (0-10)"]
# Definindo as dimensões e plotando o boxplot
plt.figure(figsize=(8, 6))
# cria dicionário de dados
boxplot_dict = sns.boxplot(dados)
plt.title('Boxplot da análise de Felicidade')
plt.xlabel('Conjunto de dados')
plt.ylabel('Valores')
plt.grid(True)
# Obtem eixos do gráfico ANTES DE MOSTRAR O GRÁFICO
ax = plt.gca()
# Acessa as linhas que representam whiskers (limites) and quartis
lines = ax.get_lines()
# As linhas são:
# 0: limite inferior, 1: limite superior, 2: mediana

# %%
prim_quartil = lines[0].get_ydata()[0] # descreve os valores pedidos
terc_quartil = lines[1].get_ydata()[0]
lim_inf_premio = lines[0].get_ydata()[1]
lim_sup_premio = lines[1].get_ydata()[1]
# obter mediana
mediana_premio = lines[4].get_ydata()[1]
print("Limite superior do boxplot:", lim_sup_premio)
print("3o quartil do boxplot:", terc_quartil)
print("Mediana do primeiro conjunto de dados:",
mediana_premio)
print("1o quartil do boxplot:", prim_quartil)
print("Limite inferior do boxplot:", lim_inf_premio)
# Out:
# Limite superior do boxplot: 100.0
# 3o quartil do boxplot: 85.0
# Mediana do primeiro conjunto de dados: 75.0
# 1o quartil do boxplot: 68.0
# Limite inferior do boxplot: 50.0

# %% [markdown]
# # Matriz de Gráfico de Dispersão

# %%
#necessário para o gráfico
import plotly.express as px
#gráfico
grafico = px.scatter_matrix(base, dimensions=['Grau de Felicidade (0-10)', 'Idade','Expectativa de Vida'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b42cee29-bd62-4bf2-ad6d-9de1b20ffdc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b42cee29-bd62-4bf2-ad6d-9de1b20ffdc8")) {                    Plotly.newPlot(                        "b42cee29-bd62-4bf2-ad6d-9de1b20ffdc8",                        [{"dimensions":[{"axis":{"matches":true},"label":"Grau de Felicidade (0-10)","values":[8.5,6.2,9.0,5.5,7.8,6.0,8.7,5.2,7.0,9.5,8.3,6.9,5.7,7.2,8.9,4.6,7.1,6.3,5.9,9.2,3.8,8.0,6.5,4.4,8.1,7.3,5.8,6.7,9.3,6.8,5.4,7.5,4.9,8.4,6.6,5.0,7.4,9.4,4.2,8.6,6.1,5.3,7.9,8.8,6.4,5.6,7.7,8.2,6.9,4.8,null,8.5,6.2,9.0,5.5,7.8,6.0,8.7,5.2,7.0,9.5,8.3,6.9,5.7,7.2,8.9,4.6,7.1,6.3,5.9,9.2,3.8,8.0,6.5,4.4,8.1,7.3,5.8,6.7,9.3,6.8,5.4,7.5,4.9,8.4,6.6,5.0,7.4,9.4,4.2,8.6,6.1,5.3,7.9,8.8,6.4,5.6,7.7,8.2,6.9,4.8]},{"axis":{"matches":true},"label":"Idade","values":[35.0,45.0,28.0,60.0,42.0,50.0,32.0,55.0,38.0,25.0,38.0,50.0,63.0,48.0,30.0,70.0,45.0,null,null,32.0,160.0,40.0,38.0,170.0,48.0,55.0,33.0,20.0,70.0,42.0,180.0,37.0,160.0,45.0,60.0,null,35.0,28.0,58.0,50.0,40.0,55.0,30.0,42.0,33.0,58.0,25.0,48.0,37.0,55.0,null,35.0,45.0,28.0,60.0,42.0,50.0,32.0,55.0,38.0,25.0,38.0,50.0,63.0,48.0,30.0,160.0,45.0,null,null,32.0,160.0,40.0,38.0,170.0,48.0,55.0,33.0,20.0,70.0,42.0,80.0,37.0,60.0,45.0,60.0,null,35.0,28.0,170.0,50.0,40.0,55.0,30.0,42.0,33.0,58.0,25.0,48.0,37.0,55.0]},{"axis":{"matches":true},"label":"Expectativa de Vida","values":[78.0,72.0,82.0,68.0,75.0,70.0,80.0,65.0,74.0,85.0,92.0,90.0,65.0,70.0,50.0,100.0,55.0,145.0,138.0,80.0,-5.0,-10.0,75.0,68.0,80.0,65.0,74.0,85.0,100.0,120.0,90.0,95.0,60.0,70.0,80.0,65.0,74.0,85.0,68.0,80.0,75.0,78.0,85.0,90.0,70.0,75.0,82.0,90.0,75.0,68.0,null,78.0,72.0,82.0,68.0,75.0,70.0,80.0,65.0,74.0,85.0,92.0,90.0,60.0,70.0,140.0,30.0,130.0,145.0,138.0,180.0,-5.0,-10.0,75.0,68.0,80.0,65.0,74.0,85.0,100.0,32.0,90.0,95.0,65.0,70.0,80.0,65.0,74.0,85.0,68.0,80.0,75.0,78.0,85.0,90.0,70.0,75.0,82.0,90.0,75.0,68.0]}],"hovertemplate":"%{xaxis.title.text}=%{x}\u003cbr\u003e%{yaxis.title.text}=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"name":"","showlegend":false,"type":"splom"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777 ...

# %% [markdown]
# # Matriz de Correlação

# %%
#separar apenas atributos numéricos
base_separada = base.loc[:, ['Grau de Felicidade (0-10)', 'Idade','Expectativa de Vida']]
# Matriz de correlação
sns.heatmap(base_separada.corr(), annot=True, cmap="Oranges")
plt.show() # exibe o grafico (ultimamente n tá mais sendo necessário, pois já exibe sozinho)
